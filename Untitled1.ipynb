# %%
import typer
import pandas as pd
import sklearn
import requests
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression

from sklearn.model_selection import GridSearchCV, RepeatedKFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
import sklearn.metrics as metrics
import mlflow
from sklearn.metrics import mean_absolute_error, r2_score
import math
from xgboost import XGBRFRegressor 
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from pycaret.regression import *
from pycaret.classification import *

# %%
data= catalog.load('filt_shot_type3pt')
data= catalog.load('filt_shot_type3pt')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 data= catalog.load('filt_shot_type3pt')
#       2 data= catalog.load('filt_shot_type3pt')
#
# NameError: name 'catalog' is not defined

# %%
data2 = pd.read_csv('/infnet-machine/data.csv')
conformed =data2[['lat','shot_type','lon','minutes_remaining','period','playoffs','shot_distance','shot_made_flag']]#.astype('float64')
conformed.dropna(inplace=True)
y_teste = conformed.iloc[:, 6:]

# %%
#import streamlit as st
import pickle
from flask import Flask, request
import requests
import pandas as pd
# escrevendo um título na página
#st.title('Minha primeira aplicação :sunglasses:')

model=pickle.load(open('/infnet-machine/model (1).pkl','rb'))

app= Flask(__name__ )

@app.route( '/predict', methods=['POST'])

def predict():
    test_json =request.get_json()
    # coletar dados 
    if test_json:
        if isinstance( test_json, dict): # unique value
            df_row =pd.DataFrame(test_json, index=[0])
        else:
            df_row = pd.DataFrame( test_json, columns=test_json[0].keys())

# prediction
        pred = model.predict(df_row)
        df_row['prediction']= pred
        return df_row.to_json(orient='records')

if __name__== '__main__':
    app.run(host='127.0.0.1', port= 5001)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5001
# Press CTRL+C to quit

# %%
import requests

# %%
url = 'http://127.0.0.1:5000'
data ={"dataframe_records":[{'0'},{'1'}]}
results=requests.post(url, json=data)
results.status_code
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 url = 'http://127.0.0.1:5000'
#       2 data ={"dataframe_records":[{'0'},{'1'}]}
# ----> 3 results=requests.post(url, json=data)
#       4 results.status_code
#
# File C:\infnet-machine\KEDRO\lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File C:\infnet-machine\KEDRO\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...

# %%
#mlflow.start_run()
data2 = pd.read_csv('/infnet-machine/data.csv')
conformed =data2[['lat','shot_type','lon','minutes_remaining','period','playoffs','shot_distance','shot_made_flag']]#.astype('float64')
conformed.dropna(inplace=True)
X = conformed.iloc[:, :] 
metricax=  conformed.shape[0]
conformed
filtrados = conformed.loc[conformed['shot_type'] == '2PT Field Goal']
filtrados
# Out:
#            lat       shot_type       lon  minutes_remaining  period  playoffs  \
# 1      34.0443  2PT Field Goal -118.4268                 10       1         0
# 2      33.9093  2PT Field Goal -118.3708                  7       1         0
# 3      33.8693  2PT Field Goal -118.1318                  6       1         0
# 4      34.0443  2PT Field Goal -118.2698                  6       2         0
# 5      34.0553  2PT Field Goal -118.4148                  9       3         0
# ...        ...             ...       ...                ...     ...       ...
# 30690  33.9443  2PT Field Goal -118.3828                 11       4         1
# 30691  34.0443  2PT Field Goal -118.2698                  7       4         1
# 30692  33.9963  2PT Field Goal -118.2688                  6       4         1
# 30694  33.8783  2PT Field Goal -118.4038                  3       4         1
# 30696  33.9723  2PT Field Goal -118.2688                  0       4         1
#
# ...

# %%
def comform_data():
    data2 = pd.read_csv('/infnet-machine/data.csv')
    conformed =data2[['lat','lon','minutes_remaining','period','playoffs','shot_distance','shot_made_flag']].astype('float64')
    conformed.dropna(inplace=True)
    #data['shot_made_flag'] = data['shot_made_flag'].astype('int').astype('float64')
    return conformed

# %%
data = comform_data()

# %%
s= setup(data, target ='shot_made_flag', session_id =123, n_jobs=-2, log_experiment='mlflow', experiment_name='regressor_nbakobe')
# Out:
# <style type="text/css">
# #T_64e5f_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_64e5f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64e5f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_64e5f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64e5f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_64e5f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_64e5f_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_64e5f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_64e5f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_64e5f_row1_col1" class="data row1 col1" >shot_made_flag</td>
#     </tr>
#     <tr>
#       <th id="T_64e5f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
exp= ClassificationExperiment()

# %%
exp.setup(data, target ='shot_made_flag', session_id =123, n_jobs=-2, log_experiment='mlflow', experiment_name='regressor_nbakobe')
# Out:
# <style type="text/css">
# #T_23605_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_23605">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23605_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_23605_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23605_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23605_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_23605_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_23605_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23605_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_23605_row1_col1" class="data row1 col1" >shot_made_flag</td>
#     </tr>
#     <tr>
#       <th id="T_23605_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
dt= exp.compare_models()
# Out:
# <style type="text/css">
# #T_a4c12 th {
#   text-align: left;
# }
# ...

# %%
def comform_data():
    data2 = pd.read_csv('/infnet-machine/data.csv')
    conformed =data2[['lat','lon','minutes_remaining','period','playoffs','shot_distance','shot_made_flag']].astype('float64')
    conformed.dropna(inplace=True)
    #data['shot_made_flag'] = data['shot_made_flag'].astype('int').astype('float64')
    return conformed

# %%
def pycaret_mlsfloww(conformed):
    s= setup(conformed, target ='shot_made_flag', session_id =123,
    n_jobs=-2, log_experiment='mlflow', experiment_name='regressor_nbakobe')
    exp= ClassificationExperiment()
    exp.setup(conformed, target ='shot_made_flag',
    session_id =123, n_jobs=-2, log_experiment='mlflow', experiment_name='regressor_nbakobe')
    best=exp.compare_models()
    save_model(best, 'my_first_pipeline')
    loaded_best_pipeline = load_model('my_first_pipeline')

    return loaded_best_pipeline

# %%
conformed=comform_data()

# %%
pycaret_mlsfloww(conformed)
# Out:
# <style type="text/css">
# #T_394ac_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_394ac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_394ac_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_394ac_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_394ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_394ac_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_394ac_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_394ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_394ac_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_394ac_row1_col1" class="data row1 col1" >shot_made_flag</td>
#     </tr>
#     <tr>
#       <th id="T_394ac_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
def svc(X,y):
    scaler = StandardScaler()
    scaler.fit(X)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
    return X_train, y_test

# %%
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
#
# NameError: name 'y' is not defined
